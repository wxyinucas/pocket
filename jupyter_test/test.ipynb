# %%
print('hello jupyter')
# Out:
# hello jupyter

# %%
import pandas as pd

# %%
a = pd.DataFrame({'a':[1, 2, 3, 4]})

# %%
a.plot(figsize=(10, 5))

# %%
# %inline plot
# Out:
# UsageError: Line magic function `%inline` not found.

# %%
# %matplotlib inline
